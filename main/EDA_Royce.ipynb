# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from utils.preprocessing_util import *

# %%
df = pd.read_csv('../data/train.csv')
#print(df.describe(include='all'))

# %%
clean_replace_numeric(df, 'flat_type', '2', 2)
clean_replace_numeric(df, 'flat_type', '3', 3)
clean_replace_numeric(df, 'flat_type', '4', 4)
clean_replace_numeric(df, 'flat_type', '5', 5)
clean_replace_numeric(df, 'flat_type', 'executive', 6)
#get_counts(df, 'flat_type')
#get_histogram(df, 'flat_type')
plot_trend(df, 'flat_type')

# %%
#get_counts(df, 'flat_model')
#get_histogram(df, 'flat_model')
plot_trend(df, 'flat_model')
# Out:
# flat_model
# 3gen                          3
# terrace                       4
# premium maisonette            6
# premium apartment loft       25
# 2-room                       34
# type s2                      46
# adjoined flat                49
# model a-maisonette           56
# type s1                     108
# dbss                        371
# model a2                    663
# maisonette                  956
# apartment                  2080
# standard                   2268
# simplified                 2798
# premium apartment          5109
# new generation            11292
# improved                  17010
# model a                   17122
# Name: count, dtype: int64

# %%
#get_counts(df, 'floor_area_sqm')
get_min(df, 'floor_area_sqm')
get_max(df, 'floor_area_sqm')
plot_trend(df, 'floor_area_sqm')
plot_scatter(df, 'floor_area_sqm', 'flat_type')
# Out:
# Min: 34.0
# Max: 215.0
